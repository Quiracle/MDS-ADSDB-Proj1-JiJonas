# %%
from os import listdir
from os.path import isfile, join, isdir

def getAllFilesRecursive(root):
    files = [ join(root,f) for f in listdir(root) if isfile(join(root,f))]
    dirs = [ d for d in listdir(root) if isdir(join(root,d))]
    for d in dirs:
        files_in_d = getAllFilesRecursive(join(root,d))
        if files_in_d:
            for f in files_in_d:
                files.append(join(root,f))
    return files

# %%
def get_destination_folder(filename: str) -> str:
    filename = filename.split('.')[0]
    if 'extended' in filename.lower():
        return f"{filename.split('_')[0]}/"
    return f"{filename.split('_')[-1]}/{filename.split('_')[0]}/"

# %%
import os
import shutil

def copy_new_files(source_folder, destination_folder):
    # Ensure the source and destination folders exist
    if not os.path.exists(source_folder):
        print(f"Source folder '{source_folder}' does not exist.")
        return
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)  # Create the destination folder if it doesn't exist

    # Get the list of files in both source and destination folders
    source_files = getAllFilesRecursive(source_folder)
    dest_files = getAllFilesRecursive(destination_folder)

    # Copy files that are not already in the destination folder
    for source_file_path in source_files:
        filename = os.path.basename(source_file_path)

        subfolder = get_destination_folder(filename)
        
        destination_subfolder = join(destination_folder + subfolder)
        if not os.path.exists(destination_subfolder):
            os.makedirs(destination_subfolder)

        dest_file_path = os.path.join(destination_subfolder, filename)

        # Only copy if the file does not exist in the destination folder
        if dest_file_path not in dest_files:
            print(f"Copying {filename} to {destination_subfolder}")
            shutil.copy2(source_file_path, dest_file_path)
        else:
            print(f"Skipping {filename}, already exists in {destination_folder}")

# %%
def extract_year_from_filename(filename):
    # Split the filename by underscores and take the first part
    year = filename.split('_')[0]
    datasource = filename.split('_')[-1].split('.')[0]
    
    # Return the extracted year as an integer
    return int(year), datasource

# %%
SOURCE = "temporal_landing"
DESTINATION = "persistent_landing"

SOURCE_FOLDER = f"../{SOURCE}/"

DESTINATION_FOLDER = f"../{DESTINATION}/"

files = copy_new_files(SOURCE_FOLDER, DESTINATION_FOLDER)

files
# Out:
# Copying 2020_01_02_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_01_08_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_01_10_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_01_13_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_01_23_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_01_24_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_01_28_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_01_30_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_02_07_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_02_10_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_02_11_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_02_13_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_02_16_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_02_17_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_02_21_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_02_26_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_03_02_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_03_03_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_03_05_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_03_07_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_03_16_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_03_19_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_03_28_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_04_05_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_04_06_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_04_13_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_04_15_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_04_16_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_04_19_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_04_25_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_04_29_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_04_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_06_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_08_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_12_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_17_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_25_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_27_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_29_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_05_31_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_01_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_02_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_03_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_04_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_05_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_06_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_13_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_17_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_06_22_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_09_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_14_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_15_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_17_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_18_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_19_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_20_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_23_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_26_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_27_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_07_29_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_01_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_02_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_03_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_04_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_05_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_06_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_07_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_09_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_12_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_15_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_17_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_21_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_26_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_29_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_08_30_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_04_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_05_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_06_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_07_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_12_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_14_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_15_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_20_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_09_28_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_06_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_07_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_14_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_15_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_16_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_17_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_19_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_24_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_25_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_27_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_30_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_10_31_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_01_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_06_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_07_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_11_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_15_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_16_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_17_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_19_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_11_25_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_03_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_04_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_07_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_09_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_10_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_11_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_12_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_14_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_28_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_12_31_idealista.json to ../persistent_landing/idealista/2020/
# Copying 2020_income.xlsx to ../persistent_landing/income/2020/
# Copying 2021_01_03_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_01_07_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_01_13_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_01_20_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_01_25_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_01_28_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_02_04_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_02_12_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_02_14_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_02_15_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_02_19_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_02_22_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_02_24_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_02_25_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_03_09_idealista.json to ../persistent_landing/idealista/2021/
# Copying 2021_income.xlsx to ../persistent_landing/income/2021/
# Copying 2024_09_27_fotocasa.json to ../persistent_landing/fotocasa/2024/
# Copying 2024_09_28_fotocasa.json to ../persistent_landing/fotocasa/2024/
# Copying 2024_10_17_idealista.json to ../persistent_landing/idealista/2024/
# Copying 2024_10_21_idealista.json to ../persistent_landing/idealista/2024/
# Copying idealista_extended.csv to ../persistent_landing/idealista/
# Copying income_opendatabcn_extended.csv to ../persistent_landing/income/
