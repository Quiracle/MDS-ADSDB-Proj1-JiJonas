# %%
pip install duckdb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 259.2 kB/s eta 0:00:43
#    ---------------------------------------- 0.1/11.0 MB 363.1 kB/s eta 0:00:30
#     --------------------------------------- 0.2/11.0 MB 871.5 kB/s eta 0:00:13
#    - -------------------------------------- 0.4/11.0 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.0 MB 1.6 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/11.0 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/11.0 MB 2.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/11.0 MB 2.5 MB/s eta 0:00:04
# ...
